# %%
# !pip install easyocr transformers torch pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: easyocr in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (1.7.2)
# Requirement already satisfied: transformers in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (5.9.0)
# Requirement already satisfied: torch in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (2.12.0)
# Requirement already satisfied: pillow in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (12.2.0)
# Requirement already satisfied: torchvision>=0.5 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (0.27.0)
# Requirement already satisfied: opencv-python-headless in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (4.13.0.92)
# Requirement already satisfied: scipy in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (1.17.1)
# Requirement already satisfied: numpy in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (2.4.6)
# Requirement already satisfied: scikit-image in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (0.26.0)
# Requirement already satisfied: python-bidi in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (0.6.10)
# Requirement already satisfied: PyYAML in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (6.0.3)
# Requirement already satisfied: Shapely in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (1.4.0)
# Requirement already satisfied: ninja in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from transformers) (1.16.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from transformers) (26.2)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.16)
# Requirement already satisfied: h11>=0.16 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from typer->transformers) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from scikit-image->easyocr) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from scikit-image->easyocr) (2026.5.15)
# Requirement already satisfied: lazy-loader>=0.4 in C:\Users\vanga\AppData\Roaming\Python\Python313\site-packages (from scikit-image->easyocr) (0.5)

# %%
import easyocr

from transformers import pipeline

from PIL import Image

import matplotlib.pyplot as plt

# %%
reader = easyocr.Reader(['en'])

print("OCR Model Loaded Successfully")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# OCR Model Loaded Successfully

# %%
sentiment_pipeline = pipeline(
    "sentiment-analysis"
)

print("Sentiment Model Loaded")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|█████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 1517.91it/s]
# Sentiment Model Loaded
